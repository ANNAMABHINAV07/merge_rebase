# %%
import seaborn as sns
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('fmri')
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
tips=sns.load_dataset('tips')

# %%
tips.groupby('day')[['total_bill','tip']].aggregate('sum','mean')
# Out:
#       total_bill     tip
# day
# Thur     1096.33  171.83
# Fri       325.88   51.96
# Sat      1778.40  260.40
# Sun      1627.16  247.39

# %%
tips.groupby('day')[['total_bill','tip']].aggregate({'total_bill':'sum','tip':'mean'}).rename(columns={'total_bill':'total','tip':'avg tip'})
# Out:
#         total   avg tip
# day
# Thur  1096.33  2.771452
# Fri    325.88  2.734737
# Sat   1778.40  2.993103
# Sun   1627.16  3.255132

# %%
tips.loc[tips.day=='Thur'][['total_bill']].reset_index()
# Out:
#     index  total_bill
# 0      77       27.20
# 1      78       22.76
# 2      79       17.29
# 3      80       19.44
# 4      81       16.66
# ..    ...         ...
# 57    202       13.00
# 58    203       16.40
# 59    204       20.53
# 60    205       16.47
# 61    243       18.78
#
# [62 rows x 2 columns]

# %%
grps=tips.groupby('day')
for idx,df in grps:
    print(idx)
    print(df)
# Out:
# Thur
#      total_bill   tip     sex smoker   day    time  size
# 77        27.20  4.00    Male     No  Thur   Lunch     4
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 81        16.66  3.40    Male     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [62 rows x 7 columns]
# Fri
#      total_bill   tip     sex smoker  day    time  size
# 90        28.97  3.00    Male    Yes  Fri  Dinner     2
# 91        22.49  3.50    Male     No  Fri  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# ...

# %%
grps.get_group('Thur').reset_index()
# Out:
#     index  total_bill   tip     sex smoker   day    time  size
# 0      77       27.20  4.00    Male     No  Thur   Lunch     4
# 1      78       22.76  3.00    Male     No  Thur   Lunch     2
# 2      79       17.29  2.71    Male     No  Thur   Lunch     2
# 3      80       19.44  3.00    Male    Yes  Thur   Lunch     2
# 4      81       16.66  3.40    Male     No  Thur   Lunch     2
# ..    ...         ...   ...     ...    ...   ...     ...   ...
# 57    202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 58    203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 59    204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 60    205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 61    243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [62 rows x 8 columns]

# %%
grps.last()
# Out:
#       total_bill   tip     sex smoker    time  size
# day
# Thur       18.78  3.00  Female     No  Dinner     2
# Fri        10.09  2.00  Female    Yes   Lunch     2
# Sat        17.82  1.75    Male     No  Dinner     2
# Sun        15.69  1.50    Male    Yes  Dinner     2

# %%
grps.head()
# Out:
#     total_bill   tip     sex smoker   day    time  size
# 0        16.99  1.01  Female     No   Sun  Dinner     2
# 1        10.34  1.66    Male     No   Sun  Dinner     3
# 2        21.01  3.50    Male     No   Sun  Dinner     3
# 3        23.68  3.31    Male     No   Sun  Dinner     2
# 4        24.59  3.61  Female     No   Sun  Dinner     4
# 19       20.65  3.35    Male     No   Sat  Dinner     3
# 20       17.92  4.08    Male     No   Sat  Dinner     2
# 21       20.29  2.75  Female     No   Sat  Dinner     2
# 22       15.77  2.23  Female     No   Sat  Dinner     2
# 23       39.42  7.58    Male     No   Sat  Dinner     4
# 77       27.20  4.00    Male     No  Thur   Lunch     4
# 78       22.76  3.00    Male     No  Thur   Lunch     2
# 79       17.29  2.71    Male     No  Thur   Lunch     2
# 80       19.44  3.00    Male    Yes  Thur   Lunch     2
# 81       16.66  3.40    Male     No  Thur   Lunch     2
# 90       28.97  3.00    Male    Yes   Fri  Dinner     2
# ...

# %%
grps.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 188       18.15  3.50  Female    Yes   Sun  Dinner     3
# 189       23.10  4.00    Male    Yes   Sun  Dinner     3
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# ...

# %%
grps.first()
# Out:
#       total_bill   tip     sex smoker    time  size
# day
# Thur       27.20  4.00    Male     No   Lunch     4
# Fri        28.97  3.00    Male    Yes  Dinner     2
# Sat        20.65  3.35    Male     No  Dinner     3
# Sun        16.99  1.01  Female     No  Dinner     2

# %%
grps.last()
# Out:
#       total_bill   tip     sex smoker    time  size
# day
# Thur       18.78  3.00  Female     No  Dinner     2
# Fri        10.09  2.00  Female    Yes   Lunch     2
# Sat        17.82  1.75    Male     No  Dinner     2
# Sun        15.69  1.50    Male    Yes  Dinner     2
